# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns

import networkx as nx

sns.set(font_scale = 1.5, style = 'darkgrid', palette='gray')
plt.rcParams['font.family'] = 'Times New Roman'

# %%
csv_file_name = '../data/degrees.csv'
df = pd.read_csv(csv_file_name, header=None, names=['network_type', 'hop', 'node1', 'node2'])
network_type_list = df.network_type.unique()
hop_list = df.hop.unique()
max_hop_list = {'scale_free_4': 6, 'random_4': 9, 'regular_4': 10}

# %%
def degree_list(graph: nx.Graph) -> list:
    return list(dict(graph.degree()).values())

def degree_analysis(graph: nx.Graph) -> tuple:
    _degree_list = degree_list(graph)
    return round(np.mean(_degree_list), 3), max(_degree_list), min(_degree_list)

result_df = pd.DataFrame(
    columns = ['network_type', 'hop', 'average_degree', 'max_degree', 'min_degree', 'average_clustering', 'average_distance']
)

# %%
# 次数配列をグラフ化
graph_dict = {}
for network_type in network_type_list:
    graph_dict[network_type] = {}
    for hop in hop_list:
        _df = df[(df.network_type == network_type) & (df.hop == hop)][['node1', 'node2']]
        edges = _df.values.tolist()
        
        graph = nx.Graph()
        graph.add_edges_from(edges)
        graph_dict[network_type][hop] = graph

# %%
# 特徴量計算
for _network_type in network_type_list:
    _max_hop = max_hop_list[_network_type]

    for _hop in range(1, _max_hop + 1):
        _graph = graph_dict[_network_type][_hop]

        _average_degree, _max_degree, _min_degree = degree_analysis(_graph)
        _average_clustering = nx.average_clustering(_graph)
        _average_distance = nx.average_shortest_path_length(_graph)
        _s = pd.Series([_network_type, _hop, _average_degree, _max_degree, _min_degree, _average_clustering, _average_distance], index=result_df.columns)
        print(_s)
        result_df = result_df.append(_s, ignore_index=True)
# Out:
# network_type          scale_free_4
# hop                              1
# average_degree               3.994
# max_degree                      69
# min_degree                       2
# average_clustering        0.029158
# average_distance          4.098052
# dtype: object
# network_type          scale_free_4
# hop                              2
# average_degree              43.026
# max_degree                     528
# min_degree                       6
# average_clustering        0.564458
# average_distance          2.278739
# dtype: object
# network_type          scale_free_4
# hop                              3
# average_degree             222.738
# max_degree                     895
# min_degree                      25
# average_clustering        0.546415
# average_distance          1.777968
# dtype: object
# network_type          scale_free_4
# hop                              4
# average_degree             637.332
# max_degree                     999
# min_degree                     146
# average_clustering        0.789649
# average_distance           1.36203
# dtype: object
# network_type          scale_free_4
# hop                              5
# average_degree             966.976
# max_degree                     999
# min_degree                     561
# average_clustering        0.974325
# average_distance          1.032056
# dtype: object
# network_type          scale_free_4
# hop                              6
# average_degree             998.528
# max_degree                     999
# min_degree                     958
# average_clustering        0.999536
# average_distance          1.000472
# dtype: object
# network_type          regular_4
# hop                           1
# average_degree            3.955
# max_degree                    4
# min_degree                    2
# average_clustering          0.0
# average_distance      16.017362
# dtype: object
# network_type          regular_4
# hop                           2
# average_degree           11.912
# max_degree                   12
# min_degree                    8
# average_clustering      0.45419
# average_distance       8.258889
# dtype: object
# network_type          regular_4
# hop                           3
# average_degree           23.871
# max_degree                   24
# min_degree                   18
# average_clustering     0.498604
# average_distance       5.673084
# dtype: object
# network_type          regular_4
# hop                           4
# average_degree           39.832
# max_degree                   40
# min_degree                   32
# average_clustering     0.529307
# average_distance       4.379725
# dtype: object
# network_type          regular_4
# hop                           5
# average_degree           59.795
# max_degree                   60
# min_degree                   50
# average_clustering     0.537552
# average_distance       3.604505
# dtype: object
# network_type          regular_4
# hop                           6
# average_degree            83.76
# max_degree                   84
# min_degree                   72
# average_clustering     0.546002
# average_distance       3.085369
# dtype: object
# network_type          regular_4
# hop                           7
# average_degree          111.727
# max_degree                  112
# min_degree                   98
# average_clustering     0.548958
# average_distance       2.720787
# dtype: object
# network_type          regular_4
# hop                           8
# average_degree          143.695
# max_degree                  144
# min_degree                  128
# average_clustering     0.552474
# average_distance        2.44024
# dtype: object
# network_type          regular_4
# hop                           9
# average_degree          179.664
# max_degree                  180
# min_degree                  162
# average_clustering     0.553884
# average_distance       2.221247
# dtype: object
# network_type          regular_4
# hop                          10
# average_degree          219.633
# max_degree                  220
# min_degree                  200
# average_clustering     0.555694
# average_distance       2.049235
# dtype: object
# network_type          random_4
# hop                          1
# average_degree             4.0
# max_degree                  10
# min_degree                   1
# average_clustering    0.002063
# average_distance      5.209844
# dtype: object
# network_type          random_4
# hop                          2
# average_degree           19.37
# max_degree                  61
# min_degree                   2
# average_clustering    0.375506
# average_distance       2.84371
# dtype: object
# network_type          random_4
# hop                          3
# average_degree          77.164
# max_degree                 198
# min_degree                   4
# average_clustering    0.318499
# average_distance      2.037832
# dtype: object
# network_type          random_4
# hop                          4
# average_degree         260.244
# max_degree                 664
# min_degree                   5
# average_clustering    0.464322
# average_distance       1.74198
# dtype: object
# network_type          random_4
# hop                          5
# average_degree         601.388
# max_degree                 943
# min_degree                  18
# average_clustering     0.73849
# average_distance       1.39804
# dtype: object
# network_type          random_4
# hop                          6
# average_degree         886.146
# max_degree                 991
# min_degree                 208
# average_clustering    0.922773
# average_distance      1.112967
# dtype: object
# network_type          random_4
# hop                          7
# average_degree         973.324
# max_degree                 999
# min_degree                 382
# average_clustering    0.982023
# average_distance      1.025702
# dtype: object
# network_type          random_4
# hop                          8
# average_degree         997.844
# max_degree                 999
# min_degree                 921
# average_clustering    0.998888
# average_distance      1.001157
# dtype: object
# network_type          random_4
# hop                          9
# average_degree         998.836
# max_degree                 999
# min_degree                 976
# average_clustering    0.999838
# average_distance      1.000164
# dtype: object

# %% [markdown]
# # 図5. スケールフリーネットワークを拡張したネットワークの特徴

# %%
fig, axes = plt.subplots(ncols = 3, nrows = 3, figsize = (15, 15))
plt.subplots_adjust(wspace=0.3, hspace=0.4)

for _hop in range(1, 7):
    _graph = graph_dict['scale_free_4'][_hop]

    # グラフ描画
    _ax = axes[int((_hop - 1) / 3)][(_hop - 1) % 3]
    sns.histplot(degree_list(_graph), ax = _ax)
    _ax.set_title('a.{}. Degree distribution (hop = {})'.format(_hop, _hop))
    _ax.set_xlabel('Degree')

    if _hop % 3 == 1:
        _ax.set_ylabel('Nodes')
    else:
        _ax.set_ylabel('')

_result_df = result_df[result_df.network_type == 'scale_free_4']

p = sns.lineplot(x='hop', y='average_degree', data=_result_df, ax = axes[2][0])
p.set_title('b. Average degree')
p.set_ylabel('Average degree')

p = sns.lineplot(x='hop', y='average_clustering', data=_result_df, ax = axes[2][1])
p.set_title('c. Average clustering coefficient')
p.set_ylabel('Average clustering coefficient')

p = sns.lineplot(x='hop', y='average_distance', data=_result_df, ax = axes[2][2])
p.set_title('d. Average distance')
p.set_ylabel('Average distance')

for _ax in axes[2]:
    _ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    _ax.set_xlabel('Expansion hop count')

plt.savefig('img/SI2_scale_free.jpg', format='jpeg', bbox_inches='tight')

# %% [markdown]
# # 図6. ランダムネットワークを拡張したネットワークの特徴

# %%
fig, axes = plt.subplots(ncols = 3, nrows = 4, figsize = (15, 20))
plt.subplots_adjust(wspace=0.3, hspace=0.4)

for _hop in range(1, 10):
    _graph = graph_dict['random_4'][_hop]

    # グラフ描画
    _ax = axes[int((_hop - 1) / 3)][(_hop - 1) % 3]
    sns.histplot(degree_list(_graph), ax = _ax)
    _ax.set_title('a.{}. Degree distribution (hop = {})'.format(_hop, _hop))
    _ax.set_xlabel('Degree')

    if _hop % 3 == 1:
        _ax.set_ylabel('Nodes')
    else:
        _ax.set_ylabel('')


_result_df = result_df[result_df.network_type == 'random_4']

p = sns.lineplot(x='hop', y='average_degree', data=_result_df, ax = axes[3][0])
p.set_title('b. Average degree')
p.set_ylabel('Average degree')

p = sns.lineplot(x='hop', y='average_clustering', data=_result_df, ax = axes[3][1])
p.set_title('c. Average clustering coefficient')
p.set_ylabel('Average clustering coefficient')

p = sns.lineplot(x='hop', y='average_distance', data=_result_df, ax = axes[3][2])
p.set_title('d. Average distance')
p.set_ylabel('Average distance')

for _ax in axes[3]:
    _ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    _ax.set_xlabel('Expansion hop count')

plt.savefig('img/SI2_random.jpg', format='jpeg', bbox_inches='tight')

# %% [markdown]
# # 図7. レギュラーネットワークを拡張したネットワークの特徴

# %%
_result_df = result_df[result_df.network_type == 'regular_4']
fig, axes = plt.subplots(ncols = 3, nrows= 1, figsize = (15, 4))
plt.subplots_adjust(wspace=0.3)

p = sns.lineplot(x='hop', y='average_degree', data=_result_df, ax = axes[0])
p.set_title('b. Degree')
p.set_ylabel('Degree')

p = sns.lineplot(x='hop', y='average_clustering', data=_result_df, ax = axes[1])
p.set_title('c. Average clustering coefficient')
p.set_ylabel('Average clustering coefficient')

p = sns.lineplot(x='hop', y='average_distance', data=_result_df, ax = axes[2])
p.set_title('d. Average distance')
p.set_ylabel('Average distance')

for _ax in axes:
    _ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    _ax.set_xlabel('Expansion hop count')

plt.savefig('img/SI2_regular.jpg', format='jpeg', bbox_inches='tight')
